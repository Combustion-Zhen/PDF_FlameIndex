# %% [markdown]
# # plot the weighted joint pdf of z, c

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from counterflow_file import *

# %%
# parameters
#models = ['IEM','IEMHYB','EMST','EMSTHYB']

params = {}
params['MIX'] = 'EMSTHYB'
params['tres'] = 1.e-2
params['tmix'] = 0.2
params['eqv'] = 1.0
params['Zfvar'] = 0.1
params['dtmix'] = 0.01
params['phif'] = 4.76

csv_name = 'pdf_zc_z-0-0.3_c-0-0.3.csv'

c_lb = 0
c_ub = 0.3
c_npts = 301

z_lb = 0
z_ub = 0.3
z_npts = 301

# points per step
pts = 10

c_all = np.linspace(c_lb, c_ub, c_npts)
z_all = np.linspace(z_lb, z_ub, z_npts)

# %%
case_name = params2name(params)

# %%
data = np.genfromtxt('/'.join([case_name,csv_name]))

# %%
plt.imshow(data,
           origin='lower',
           extent=[0, 0.3, 0, 0.3],
           cmap='Blues',
           norm = colors.Normalize(vmin = 0, vmax = 20),
          )
#plt.plot([0.055, 0.055],[0, 0.3],'k--')
plt.colorbar()

# %%
data = np.genfromtxt('/'.join([case_name, 'ZCTR.csv']),delimiter=',',names=True)

# %%
plt.hist2d(data['Z'],data['C'],bins=100,normed=True,weights=data['R'],cmap='Blues')
# Out:
# (array([[  1.26312369e+04,   2.44621074e+03,   1.55148136e+03, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  3.42898264e+00,   1.73528174e+00,   8.74096482e-01, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  2.62649342e+00,   4.80811248e-01,   4.99054775e-01, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         ...,
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  3.89485106e-02,   0.00000000e+00,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  7.74135753e-02,   0.00000000e+00,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00]]),
#  array([  2.13125079e-05,   7.55235823e-03,   1.50834039e-02,
#           2.26144497e-02,   3.01454954e-02,   3.76765411e-02,
# ...
